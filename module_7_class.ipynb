# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Módulos & Pacotes
# Caderno de **Aula**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>from / import / as;</li>
#   <li>Módulo;</li>
#   <li>Pacote;</li>
#   <li>Baixando pacotes.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Aulas**

# %% [markdown]
# ## 1\. from / import / as

# %% [markdown]
# Os módulos nativos do Python podem ser encontrados neste [link](https://docs.python.org/3/py-modindex.html).

# %% [markdown]
# ### **1.1. import**

# %% [markdown]
# **Exemplo:** `random`

# %%
import random

# %%
escolha = random.choice([1, 2, 3])
print(escolha)

# %%
numero_aleatorio = random.random() # entre [0,1)
print(numero_aleatorio)

# %% [markdown]
# **Exemplo:** `math`

# %%
import math

# %%
potencia = math.pow(10, 10)
print(potencia)

# %%
num = math.ceil(10.1)
print(num)

# %%
print(math.pi)

# %% [markdown]
# ### **1.2. from, import**

# %% [markdown]
# **Exemplo:** `time`

# %%
from time import time

# %%
print(time())

# %%
sleep(5)

# %%
from time import time, sleep

# %%
sleep(5)

# %% [markdown]
# ### **1.3. from, import, as**

# %% [markdown]
# **Exemplo:** `datetime`

# %%
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2022-10-20 09:53:31.010851

# %%
print(dt.now().day)
# Out:
# 20

# %%
print(dt.now().year)
# Out:
# 2022

# %% [markdown]
# ## 2\. Módulos

# %% [markdown]
# ### **2.1. Motivação**

# %% [markdown]
#  - Classe Arquivo CSV

# %%
class ArquivoCSV(object):

  def __init__(self, arquivo: str):
    self.arquivo = arquivo
    self.conteudo = self._extrair_conteudo()
    self.colunas = self._extrair_nome_colunas()

  def _extrair_conteudo(self):
    conteudo = None
    with open(file=self.arquivo, mode='r', encoding='utf8') as arquivo:
      conteudo = arquivo.readlines()
    return conteudo

  def _extrair_nome_colunas(self):
    return self.conteudo[0].strip().split(sep=',')

  def extrair_coluna(self, indice_coluna: str):
    coluna = list()
    for linha in self.conteudo:
      conteudo_linha = linha.strip().split(sep=',')
      coluna.append(conteudo_linha[indice_coluna])
    coluna.pop(0)
    return coluna

# %% [markdown]
#  - Arquivo banco.csv

# %%
# %%writefile banco.csv
# age,job,marital,education,default,balance,housing,loan
# 30,unemployed,married,primary,no,1787,no,no
# 33,services,married,secondary,no,4789,yes,yes
# 35,management,single,tertiary,no,1350,yes,no
# 30,management,married,tertiary,no,1476,yes,yes
# 59,blue-collar,married,secondary,no,0,yes,no
# 35,management,single,tertiary,no,747,no,no
# 36,self-employed,married,tertiary,no,307,yes,no
# 39,technician,married,secondary,no,147,yes,no
# 41,entrepreneur,married,tertiary,no,221,yes,no
# 43,services,married,primary,no,-88,yes,yes

# %%
arquivo_banco = ArquivoCSV(arquivo='./banco.csv')

# %% [markdown]
#  - Extraindo a coluna de `education`

# %%
education = arquivo_banco.extrair_coluna(indice_coluna=3)
print(education)

# %% [markdown]
# ### **2.2. Definição**

# %% [markdown]
# Vamos criar um módulo (arquivo) com o nome `arquivo_csv.py` com o código da classe `ArquivoCSV`.

# %% [markdown]
# ### **2.3. Revisitando a motivação**

# %% [markdown]
# Vamos importar a classe `ArquivoCSV` do módulo (arquivo) `arquivo_csv.py`.

# %%
from arquivo_csv import ArquivoCSV

arquivo_banco_modulo = ArquivoCSV(arquivo='./banco.csv')

# %%
education = arquivo_banco_modulo.extrair_coluna(indice_coluna=3)
print(education)

# %% [markdown]
# ## 3\. Pacotes

# %% [markdown]
# ### **3.1. Motivação**

# %% [markdown]
#  - Classe Arquivo Texto

# %%
class ArquivoTXT(object):

  def __init__(self, arquivo: str):
    self.arquivo = arquivo
    self.conteudo = self._extrair_conteudo()

  def _extrair_conteudo(self):
    conteudo = None
    with open(file=self.arquivo, mode='r', encoding='utf8') as arquivo:
      conteudo = arquivo.readlines()
    return conteudo

  def extrair_linha(self, numero_linha: int):
    return self.conteudo[numero_linha-1]

# %% [markdown]
#  - Arquivo noticia.txt

# %%
# %%writefile noticia.txt
# Egito cobra quase US$ 1 bi para liberar navio que bloqueou Canal de Suez
# Segundo autoridades, valor será utilizado para recompor as perdas provocados pelo encalhamento da embarcação de quase 400 metros

# %%
arquivo_noticia = ArquivoTXT(arquivo='./noticia.txt')

# %%
titulo = arquivo_noticia.extrair_linha(numero_linha=1)
print(titulo)

# %% [markdown]
# ### **3.2. Definição**

# %% [markdown]
# Vamos criar um módulo (arquivo) com o nome `arquivo_txt.py` com o código da classe `ArquivoTXT`.

# %% [markdown]
# Vamos criar um pacote (pasta) com o nome arquivo e mover os módulos (arquivos) `arquivo_csv.py` e `arquivo_txt.py` para ela.

# %% [markdown]
# ### **3.3. Revisitando a motivação**

# %%
from arquivo.arquivo_csv import ArquivoCSV
from arquivo.arquivo_txt import ArquivoTXT

# %%
arquivo_banco_pacote = ArquivoCSV(arquivo='./banco.csv')
arquivo_noticia_pacote = ArquivoTXT(arquivo='./noticia.txt')

# %%
education = arquivo_banco_pacote.extrair_coluna(indice_coluna=3)
print(education)

# %%
titulo = arquivo_noticia_pacote.extrair_linha(numero_linha=1)
print(titulo)

# %% [markdown]
# ## 4\. Baixando pacotes

# %% [markdown]
# ### **4.1. PyPI**

# %% [markdown]
# Repositório oficial de pacotes Python ([link](https://pypi.org/)).

# %% [markdown]
# ### **4.2. PIP**

# %% [markdown]
# Ferramenta oficial para instalar pacotes Python armazenados no PyPI.

# %% [markdown]
#  - Instalando pacotes: `pip install <pacote>==<versão>`

# %%
# !pip install requests==2.28.1
# Out:
# Collecting requests==2.28.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 KB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\administrator\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1) (1.26.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\administrator\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1) (3.3)
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.0
#     Uninstalling requests-2.28.0:
#       Successfully uninstalled requests-2.28.0
# Successfully installed requests-2.28.1
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\Administrator\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
#  - Listando pacotes: `pip freeze`

# %%
# !pip freeze
# Out:
# asttokens==2.0.8
# async-generator==1.10
# attrs==21.4.0
# backcall==0.2.0
# browser-cookie3==0.14.3
# certifi==2022.5.18.1
# cffi==1.15.0
# cfgv==3.3.1
# charset-normalizer==2.0.12
# click==8.1.3
# colorama==0.4.4
# cryptography==37.0.2
# debugpy==1.6.3
# decorator==5.1.1
# distlib==0.3.4
# docker==4.2.2
# emoji==1.7.0
# entrypoints==0.4
# executing==1.1.0
# filelock==3.7.1
# Flask==2.1.2
# h11==0.13.0
# identify==2.5.1
# idna==3.3
# ipykernel==6.16.0
# ipython==8.5.0
# irc==20.0.0
# itsdangerous==2.1.2
# jaraco.classes==3.2.1
# jaraco.collections==3.5.1
# jaraco.context==4.1.1
# jaraco.functools==3.5.0
# jaraco.logging==3.1.0
# jaraco.stream==3.0.3
# jaraco.text==3.8.0
# jedi==0.18.1
# jeepney==0.8.0
# Jinja2==3.1.2
# jupyter-core==4.11.1
# jupyter_client==7.3.5
# keyring==23.6.0
# lib==4.0.0
# lz4==4.0.1
# MarkupSafe==2.1.1
# matplotlib-inline==0.1.6
# millify==0.1.1
# more-itertools==8.13.0
# nest-asyncio==1.5.5
# nodeenv==1.6.0
# numpy==1.22.4
# outcome==1.1.0
# packaging==21.3
# pandas==1.4.2
# parso==0.8.3
# pbkdf2==1.3
# pickleshare==0.7.5
# Pillow==9.1.1
# platformdirs==2.5.2
# pre-commit==2.19.0
# prompt-toolkit==3.0.31
# psutil==5.9.2
# pure-eval==0.2.2
# pyaes==1.6.1
# pycparser==2.21
# pycryptodome==3.14.1
# Pygments==2.13.0
# pyOpenSSL==22.0.0
# pyparsing==3.0.9
# pypiwin32==223
# PySocks==1.7.1
# python-dateutil==2.8.2
# pytz==2022.1
# pywin32==304
# pywin32-ctypes==0.2.0
# PyYAML==6.0
# pyzmq==24.0.1
# requests==2.28.1
# SecretStorage==3.3.2
# selenium==4.2.0
# six==1.16.0
# sniffio==1.2.0
# sortedcontainers==2.4.0
# stack-data==0.5.1
# tempora==5.0.1
# toml==0.10.2
# tornado==6.2
# traitlets==5.4.0
# trio==0.21.0
# trio-websocket==0.9.2
# Twitch-Channel-Points-Miner-v2==2.1.1
# urllib3==1.26.9
# virtualenv==20.14.1
# wcwidth==0.2.5
# websocket-client==1.3.2
# Werkzeug==2.1.2
# wsproto==1.1.0

# %%
# !pip install -r requirements.txt

# %% [markdown]
#  - Removendo pacotes: `pip uninstall <pacote>`

# %%
# !pip uninstall requests

# %% [markdown]
# ### **4.3. Requests**

# %% [markdown]
# Pacote para interação com o protocolo web HTTP ([link](https://pypi.org/project/requests/)).

# %% [markdown]
# **Exemplo:** Extrair a taxa CDI do site da B3.

# %%
import requests as req

response = req.get('https://www2.cetip.com.br/ConsultarTaxaDi/ConsultarTaxaDICetip.aspx')

# %%
print(f'status code: {response.status_code}')
# Out:
# status code: 200

# %%
print(response.text)
# Out:
# {"taxa":"13,65","dataTaxa":"19/10/2022","indice":"36.934,49","dataIndice":"20/10/2022"}

# %%
import json

data = json.loads(response.text)
print(data)
print(type(data))
# Out:
# {'taxa': '13,65', 'dataTaxa': '19/10/2022', 'indice': '36.934,49', 'dataIndice': '20/10/2022'}
# <class 'dict'>

# %%
cdi = None

for key, value in data.items():
  if key == 'taxa':
    cdi = value.replace(',', '.')
    cdi = float(cdi)

print(cdi)
print(type(cdi))
# Out:
# 13.65
# <class 'float'>
